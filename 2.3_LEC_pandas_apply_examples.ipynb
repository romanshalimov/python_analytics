# %% [markdown]
# # Создание столбцов на ходу
# - Лена - разработчик
# - Ваня - дизайнер
# - Настя - редактор

# %%
import pandas as pd

# %%
def departments(row):
    # row['разработка'] = 1  # создается новый столбец
    info = row['dicts']
    # print(info)
    
    if 'Лена' in info:
        row['разработка'] = info['Лена']
        
    if 'Настя' in info:
        row['редакторы'] = info['Настя']
    
    return row

# %%
df = df.apply(departments, axis=1).fillna(0)
df
# Out:
#                     dicts  разработка  редакторы
# 0  {'Лена': 1, 'Ваня': 2}         1.0        0.0
# 1  {'Ваня': 3, 'Леша': 5}         0.0        0.0
# 2            {'Настя': 3}         0.0        3.0

# %%
df.astype({'разработка': 'int32'})
# Out:
#                     dicts  разработка  редакторы
# 0  {'Лена': 1, 'Ваня': 2}           1        0.0
# 1  {'Ваня': 3, 'Леша': 5}           0        0.0
# 2            {'Настя': 3}           0        3.0

# %%
df = pd.DataFrame({'dicts': [{'Лена': 1, 'Ваня': 2}, {'Ваня': 3, 'Леша': 5}, {'Настя': 3}]})
df
# Out:
#                     dicts
# 0  {'Лена': 1, 'Ваня': 2}
# 1  {'Ваня': 3, 'Леша': 5}
# 2            {'Настя': 3}

# %% [markdown]
# # Группировки и оконные функции

# %%
df = pd.DataFrame(
    {
        'region': ['СФО', 'СФО', 'ДВФО', 'СФО', 'ДВФО', 'ДВФО', 'ДВФО', 'ДВФО', 'СФО', 'ДВФО'],
        'city': ['Новосибирск', 'Томск', 'Владивосток', 'Новосибирск', 'Владивосток', 'Владивосток', 'Владивосток', 'Владивосток', 'Томск', 'Владивосток'],
        'sales': [140, 135, 290, 95, 100, 50, 40, 120, 190, 200],
    }
)
df
# Out:
#   region         city  sales
# 0    СФО  Новосибирск    140
# 1    СФО        Томск    135
# 2   ДВФО  Владивосток    290
# 3    СФО  Новосибирск     95
# 4   ДВФО  Владивосток    100
# 5   ДВФО  Владивосток     50
# 6   ДВФО  Владивосток     40
# 7   ДВФО  Владивосток    120
# 8    СФО        Томск    190
# 9   ДВФО  Владивосток    200

# %%
df['region'].unique()
# Out:
# array(['СФО', 'ДВФО'], dtype=object)

# %%
df_sfo = df[df['region'] == 'СФО']
df_sfo
# Out:
#   region         city  sales
# 0    СФО  Новосибирск    140
# 1    СФО        Томск    135
# 3    СФО  Новосибирск     95
# 8    СФО        Томск    190

# %%
df_sfo.count()  # количество строк с ненулевыми значениями
# Out:
# region    4
# city      4
# sales     4
# dtype: int64

# %%
df.groupby('region').count()
# Out:
#         city  sales
# region
# ДВФО       6      6
# СФО        4      4

# %% [markdown]
# Посчитать размах значений

# %%
df
# Out:
#   region         city  sales
# 0    СФО  Новосибирск    140
# 1    СФО        Томск    135
# 2   ДВФО  Владивосток    290
# 3    СФО  Новосибирск     95
# 4   ДВФО  Владивосток    100
# 5   ДВФО  Владивосток     50
# 6   ДВФО  Владивосток     40
# 7   ДВФО  Владивосток    120
# 8    СФО        Томск    190
# 9   ДВФО  Владивосток    200

# %%
df_sfo
# Out:
#   region         city  sales
# 0    СФО  Новосибирск    140
# 1    СФО        Томск    135
# 3    СФО  Новосибирск     95
# 8    СФО        Томск    190

# %%
min_sales = df_sfo['sales'].min()
min_sales
# Out:
# 95

# %%
max_sales = df_sfo['sales'].max()
max_sales
# Out:
# 190

# %%
max_sales - min_sales
# Out:
# 95

# %%
def min_max(df):
    min_sales = df['sales'].min()
    max_sales = df['sales'].max()
    
    return max_sales - min_sales

# %%
df.groupby('region')

# %%
df.groupby('region').apply(min_max)  # на выход функции подается датафрейм вроде df_sfo
# Out:
# region
# ДВФО    250
# СФО      95
# dtype: int64

# %%
df.groupby(['region', 'city']).apply(min_max)
# Out:
# region  city
# ДВФО    Владивосток    250.0
# СФО     Новосибирск      0.0
#         Томск          190.0
# dtype: float64

# %% [markdown]
# # Группировки с пустыми значениями

# %%
df = pd.DataFrame(
    {
        'region': ['СФО', 'СФО', 'ДВФО', 'СФО', 'ДВФО', 'ДВФО', 'ДВФО', 'ДВФО', 'СФО', None],
        'city': ['Новосибирск', 'Томск', 'Владивосток', 'Новосибирск', 'Владивосток', 'Владивосток', 'Владивосток', 'Владивосток', 'Томск', 'Владивосток'],
        'sales': [None, 0, 290, 95, 100, 50, 40, 120, 190, 200],
    }
)
df
# Out:
#   region         city  sales
# 0    СФО  Новосибирск    NaN
# 1    СФО        Томск    0.0
# 2   ДВФО  Владивосток  290.0
# 3    СФО  Новосибирск   95.0
# 4   ДВФО  Владивосток  100.0
# 5   ДВФО  Владивосток   50.0
# 6   ДВФО  Владивосток   40.0
# 7   ДВФО  Владивосток  120.0
# 8    СФО        Томск  190.0
# 9   None  Владивосток  200.0

# %%
df['region'].value_counts()  # группировка НЕ учитывает строки с пустым ключом
# Out:
# ДВФО    5
# СФО     4
# Name: region, dtype: int64

# %%
df['region'].value_counts().index
# Out:
# Index(['ДВФО', 'СФО'], dtype='object')

# %%
df['region'].value_counts().values
# Out:
# array([5, 4])

# %%
df.groupby('region').count()  # метод count возвращает количетство НЕПУСТЫХ строк
# Out:
#         city  sales
# region
# ДВФО       5      5
# СФО        4      3

# %% [markdown]
# ### Метод agg

# %%
df
# Out:
#   region         city  sales
# 0    СФО  Новосибирск    NaN
# 1    СФО        Томск    0.0
# 2   ДВФО  Владивосток  290.0
# 3    СФО  Новосибирск   95.0
# 4   ДВФО  Владивосток  100.0
# 5   ДВФО  Владивосток   50.0
# 6   ДВФО  Владивосток   40.0
# 7   ДВФО  Владивосток  120.0
# 8    СФО        Томск  190.0
# 9   None  Владивосток  200.0

# %%
df.groupby('region').count()
# Out:
#         city  sales
# region
# ДВФО       5      5
# СФО        4      3

# %%
df.groupby('region').agg({'sales': 'count', 'city': ['count', 'min']})
# Out:
#        sales  city
#        count count          min
# region
# ДВФО       5     5  Владивосток
# СФО        3     4  Новосибирск

# %%
df.groupby('region').agg({'sales': ['count', min_max], 'city': ['count', 'min']})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     286             try:
# --> 287                 return self._python_agg_general(func, *args, **kwargs)
#     288             except KeyError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1480                 # if this function is invalid for this dtype, we will ignore it.
# -> 1481                 result = self.grouper.agg_series(obj, f)
#    1482             except TypeError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     980         else:
# --> 981             result = self._aggregate_series_pure_python(obj, func)
#     982
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#    1004             group = group.__finalize__(obj, method="groupby")
# -> 1005             res = func(group)
#    1006             res = libreduction.extract_result(res)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1466         func = com.is_builtin_func(func)
# -> 1467         f = lambda x: func(x, *args, **kwargs)
#    1468
#
# <ipython-input-28-fed892ac6ed2> in min_max(df)
#       1 def min_max(df):
# ----> 2     min_sales = df['sales'].min()
#       3     max_sales = df['sales'].max()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#
# KeyError: 'sales'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-a1d8d4084517> in <module>
# ----> 1 df.groupby('region').agg({'sales': ['count', min_max], 'city': ['count', 'min']})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     867
#     868         op = GroupByApply(self, func, args, kwargs)
# --> 869         result = op.agg()
#     870         if not is_dict_like(func) and result is not None:
#     871             return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in agg(self)
#     166
#     167         if is_dict_like(arg):
# --> 168             return self.agg_dict_like()
#     169         elif is_list_like(arg):
#     170             # we require a list, but not a 'str'
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     473         else:
#     474             # key used for column selection and output
# --> 475             results = {
#     476                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     477             }
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in <dictcomp>(.0)
#     474             # key used for column selection and output
#     475             results = {
# --> 476                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     477             }
#     478
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     269             # but not the class list / tuple itself.
#     270             func = maybe_mangle_lambdas(func)
# --> 271             ret = self._aggregate_multiple_funcs(func)
#     272             if relabeling:
#     273                 # error: Incompatible types in assignment (expression has type
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg)
#     324
#     325             key = base.OutputKey(label=name, position=idx)
# --> 326             results[key] = self.aggregate(func)
#     327
#     328         if any(isinstance(x, DataFrame) for x in results.values()):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     289                 # TODO: KeyError is raised in _python_agg_general,
#     290                 #  see test_groupby.test_basic
# --> 291                 result = self._aggregate_named(func, *args, **kwargs)
#     292
#     293                 # result is a dict whose keys are the elements of result_index
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _aggregate_named(self, func, *args, **kwargs)
#     413             object.__setattr__(group, "name", name)
#     414
# --> 415             output = func(group, *args, **kwargs)
#     416             output = libreduction.extract_result(output)
#     417             if not initialized:
#
# <ipython-input-28-fed892ac6ed2> in min_max(df)
#       1 def min_max(df):
# ----> 2     min_sales = df['sales'].min()
#       3     max_sales = df['sales'].max()
#       4
#       5     return max_sales - min_sales
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'sales'

# %% [markdown]
# Функция min_max_agg для метода agg

# %%
def min_max_agg(df_column):  # на вход подается конкретный столбец
    min_sales = df_column.min()
    max_sales = df_column.max()
    
    return max_sales - min_sales

# %%
df.groupby('region').agg({'sales': ['count', min_max_agg], 'city': ['count', min]})
# Out:
#        sales              city
#        count min_max_agg count          min
# region
# ДВФО       5       250.0     5  Владивосток
# СФО        3       190.0     4  Новосибирск

# %% [markdown]
# ### Посчитать процент строки от ее региона

# %%
df = pd.DataFrame(
    {
        'region': ['СФО', 'СФО', 'ДВФО', 'СФО', 'ДВФО', 'ДВФО', 'ДВФО', 'ДВФО', 'СФО', 'ДВФО'],
        'city': ['Новосибирск', 'Томск', 'Владивосток', 'Новосибирск', 'Владивосток', 'Владивосток', 'Владивосток', 'Владивосток', 'Томск', 'Владивосток'],
        'sales': [140, 135, 290, 95, 100, 50, 40, 120, 190, 200],
    }
)
df.sort_values(['region', 'city'])
# Out:
#   region         city  sales
# 2   ДВФО  Владивосток    290
# 4   ДВФО  Владивосток    100
# 5   ДВФО  Владивосток     50
# 6   ДВФО  Владивосток     40
# 7   ДВФО  Владивосток    120
# 9   ДВФО  Владивосток    200
# 0    СФО  Новосибирск    140
# 3    СФО  Новосибирск     95
# 1    СФО        Томск    135
# 8    СФО        Томск    190

# %%
a = [1, 2, 3]
b = a.copy()

# %%
df_dv = df.copy()

df_dv = df_dv[df_dv['region'] == 'ДВФО']
df_dv
# Out:
#   region         city  sales
# 2   ДВФО  Владивосток    290
# 4   ДВФО  Владивосток    100
# 5   ДВФО  Владивосток     50
# 6   ДВФО  Владивосток     40
# 7   ДВФО  Владивосток    120
# 9   ДВФО  Владивосток    200

# %%
sum_sales = df_dv['sales'].sum()
sum_sales
# Out:
# 800

# %%
df_dv['share'] = df_dv['sales'] / sum_sales
df_dv
# Out:
#   region         city  sales   share
# 2   ДВФО  Владивосток    290  0.3625
# 4   ДВФО  Владивосток    100  0.1250
# 5   ДВФО  Владивосток     50  0.0625
# 6   ДВФО  Владивосток     40  0.0500
# 7   ДВФО  Владивосток    120  0.1500
# 9   ДВФО  Владивосток    200  0.2500

# %%
def share(df):
    sum_sales = df['sales'].sum()
    df['share'] = df['sales'] / sum_sales
    
    return df

# %%
df.groupby('region').apply(share).sort_values(['region', 'city'])
# Out:
#   region         city  sales     share
# 2   ДВФО  Владивосток    290  0.362500
# 4   ДВФО  Владивосток    100  0.125000
# 5   ДВФО  Владивосток     50  0.062500
# 6   ДВФО  Владивосток     40  0.050000
# 7   ДВФО  Владивосток    120  0.150000
# 9   ДВФО  Владивосток    200  0.250000
# 0    СФО  Новосибирск    140  0.250000
# 3    СФО  Новосибирск     95  0.169643
# 1    СФО        Томск    135  0.241071
# 8    СФО        Томск    190  0.339286

# %%
df.groupby(['region', 'city']).apply(share).sort_values(['region', 'city'])
# Out:
#   region         city  sales     share
# 2   ДВФО  Владивосток    290  0.362500
# 4   ДВФО  Владивосток    100  0.125000
# 5   ДВФО  Владивосток     50  0.062500
# 6   ДВФО  Владивосток     40  0.050000
# 7   ДВФО  Владивосток    120  0.150000
# 9   ДВФО  Владивосток    200  0.250000
# 0    СФО  Новосибирск    140  0.595745
# 3    СФО  Новосибирск     95  0.404255
# 1    СФО        Томск    135  0.415385
# 8    СФО        Томск    190  0.584615
