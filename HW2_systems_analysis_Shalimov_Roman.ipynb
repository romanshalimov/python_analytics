# %% [markdown]
# # Оглавление
#
# **[Оглавление](#оглавление) 1**
#
# **[Введение](#введение) 2**
#
# **[Общее описание задачи](#общее-описание-задачи) 2**
#
# > [Изменения функционала системы](#изменения-функционала-системы) 3
# >
# > [Имеющийся функционал](#имеющийся-функционал) 3
# >
# > [Новые функции системы](#новые-функции-системы) 4
# >
# > [Изменения в бизнес-процессе](#изменения-в-бизнес-процессе) 5
# >
# > [Текущий процесс](#текущий-процесс) 5
# >
# > [Изменения в бизнес-процессе](#section-1) 6
#
# **[Функциональные требования](#функциональные-требования) 7**
#
# > [ВИ: Выбор адреса из предложенного
# > списка](#ви-выбор-адреса-из-предложенного-списка) 7
# >
# > [ВИ: Сообщить клиенту, что адрес будет уточнён по
# > телефону](#ви-сообщить-клиенту-что-адрес-будет-уточнён-по-телефону) 7
# >
# > [ВИ: Просмотр результата проверки точности
# > адреса](#ви-просмотр-результата-проверки-точности-адреса) 8
#
# **[Нефункциональные требования](#нефункциональные-требования) 9**
#
# > [Требования к пользовательскому
# > интерфейсу](#требования-к-пользовательскому-интерфейсу) 9
# >
# > [Форма оформления доставки](#форма-оформления-доставки) 9
# >
# > [Форма просмотра списка заказов](#форма-просмотра-списка-заказов) 9
# >
# > [Требования к интеграции с сервисом
# > DADATA](#требования-к-интеграции-с-сервисом-dadata) 10
# >
# > [Отправка запроса на проверку
# > адреса](#отправка-запроса-на-проверку-адреса) 10
# >
# > [Проверка уровня выбранного
# > адреса](#проверка-уровня-выбранного-адреса) 10
# >
# > [Маппинг данных существующего
# > метода](#маппинг-данных-существующего-метода) 10
# >
# > [Доработка метода отправки заказа](#доработка-метода-отправки-заказа)
# > 11
#
# #
#
# # Введение
#
# Для сокращения издержек, связанных с необходимостью проверять и уточнять
# адрес доставки, необходимо автоматизировать проверку введённого клиентом
# (пользователь интернет-магазина) адреса на форме оформления заказа.
#
# Доработка затрагивает клиентскую и серверную части интернет-магазина.
#
# Заказчик доработки: Отдел продаж интернет-магазина.
#
# # Общее описание задачи
#
# На форме оформления заказа заменить имеющиеся поля ввода адреса на одно
# поле.
#
# Для автоматической проверки адреса использовать сервис DADATA.
#
# При заполнении единого поля адреса должны отображаться подсказки
# полученные от сервиса DADATA.
#
# Проверенным адресом является адрес определённый до уровня 8 (Дом) в
# ФИАС.
#
# На форме просмотра оформленных заказов добавить атрибут, указывающий
# результат автоматической проверки адреса.
#
# Если адрес не был проверен, клиенту должно отображаться соответствующее
# уведомление.
#
# ## Изменения функционала системы
#
# ### Имеющийся функционал
#
# <img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image6.png"
# style="width:6.26772in;height:6.31944in" />
#
# ### Новые функции системы
#
# -   Выбор адреса из предложенного списка
#
# -   Сообщить клиенту, что адрес будет уточнен по телефону
#
# -   Просмотр результата проверки точности адреса
#
# <img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image7.png"
# style="width:4.20591in;height:5.60137in" />
#
# ## Изменения в бизнес-процессе
#
# ### Текущий процесс<img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image5.png"
# style="width:6.26772in;height:7.27778in" />
#
# ###
#
# ### Изменения в бизнес-процессе
#
# Если указанный адрес был определён до уровня Дом (8) в системе ФИАС,
# адрес считается проверенным и проверять его в ручную не нужно.
#
# <img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image3.png"
# style="width:6.26772in;height:7.26389in" />
#
# # Функциональные требования
#
# ## ВИ: Выбор адреса из предложенного списка
#
# Предусловие: В ходе сценария "Оформление доставки" клиент вводит адрес
# доставки
#
# Основной сценарий:
#
# 1.  Клиент заполняет поле адрес
#
# 2.  Введённый адрес отправляется в системы подсказок, система подсказок
#     > возвращает список подходящих адресов
#
# 3.  Клиент выбирает один из предложенных адресов
#
#     1.  Если клиент продолжил вводить адрес, вернуться на пункт 1
#
# 4.  Клиент возвращается в сценарий "Оформление доставки"
#
# Альтернативный сценарий 1:
#
# 1.  Клиент заполняет поле адрес
#
# 2.  Введённый адрес отправляется в системы подсказок, система подсказок
#     > возвращает список подходящих адресов
#
# 3.  Клиент игнорирует предложенные адреса
#
# 4.  Клиент возвращается в сценарий "Оформление доставки"
#
# Альтернативный сценарий 2:
#
# 1.  Клиент заполняет поле адрес
#
# 2.  Введённый адрес отправляется в системы подсказок, система подсказок
#     > не отвечает или не может определить адрес
#
# 3.  Клиент возвращается в сценарий "Оформление доставки"
#
# ## ВИ: Сообщить клиенту, что адрес будет уточнён по телефону
#
# Предусловие:
#
# -   В ходе сценария "Оформление доставки" клиент нажимает кнопку
#     > "Продолжить" на кране заполнения адреса
#
# -   При этом клиент не воспользовался сценарием "Выбор адреса из
#     > предложенного списка" или Система подсказок не смогла определить
#     > адрес доставки до дома
#
# Основной сценарий:
#
# 1.  Клиенту отображается диалоговое окно с текстом "Не удалось
#     > определить адрес с точностью до дома. С вами свяжется оператор для
#     > уточнения адреса доставки" и кнопками "Вернуться" и "Продолжить".
#
# 2.  Клиент нажимает "Продолжить" и переходить на следующий шаг сценария
#     > "Оформление доставки"
#
# Альтернативный сценарий:
#
# 1.  Клиенту отображается диалоговое окно с текстом "Не удалось
#     > определить адрес с точностью до дома. С вами свяжется оператор для
#     > уточнения адреса доставки" и кнопками "Вернуться" и "Продолжить".
#
# 2.  Клиент нажимает "Вернуться" и возвращается на шаг ввода адреса
#     > сценария "Оформление доставки"
#
# ## ВИ: Просмотр результата проверки точности адреса
#
# Предусловие: Заказ оформлен с доставкой к клиенту
#
# Основной сценарий:
#
# 1.  Если адрес доставки был определён системой подсказок с точность до
#     > дома, адрес доставки помечен как проверенный.
#
# Альтернативный сценарий:
#
# 1.  Если адрес доставки не был определён системой подсказок с точность
#     > до дома, адрес доставки помечен как не проверенный.
#
# # Нефункциональные требования
#
# ## Требования к пользовательскому интерфейсу
#
# ### Форма оформления доставки
#
# <img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image1.png"
# style="width:6.26772in;height:4.61111in" />
#
# Поле “Адрес доставки” становиться единым.
#
# ### Форма просмотра списка заказов
#
# <img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image2.png"
# style="width:6.26772in;height:2.19444in" />
#
# На форме просмотра оформленных заказов, добавить столбец с результатом
# автоматической проверки адреса.
#
# ## Требования к интеграции с сервисом DADATA
#
# ### Отправка запроса на проверку адреса
#
# При вводе символов в поле “Адрес доставки”, с задержкой 1 сек, введённый
# адрес отправляется в сервис DADATA.
#
# Описание метода
# [<u>https://dadata.ru/api/suggest/address/</u>](https://dadata.ru/api/suggest/address/)
#
# Полученные в ответе адреса, отображаются клиенту для выбора.
#
# ### Проверка уровня выбранного адреса
#
# Если клиент выбрал адрес из предложенного списка и нажал на кнопку
# “Продолжить”,
#
# проверяется уровень адреса по ФИАС.
#
# Значение берётся из поля ***data.fias_level***
#
# <img
# src="attachment:vertopal_58b598c25c42435e82055ec266bc17bc/media/image4.png"
# style="width:6.26772in;height:2.06944in" />
#
# Если значение поля ***data.fias_level*** больше или равно 8,
# осуществляется переход на следующий шаг.
#
# Иначе пользователю отображается диалоговое окно с текстом "Не удалось
# определить адрес с точностью до дома. С вами свяжется оператор для
# уточнения адреса доставки" и кнопками "Вернуться" и "Продолжить".
#
# ### Маппинг данных существующего метода
#
# Если клиент выбрал адрес из предложенного списка и отправил заказ на
# обработку (метод POST
# [<u>https://myshop.ru/order/</u>](https://myshop.ru/order/)), данные
# полученные от сервиса DADATA отправляются на сервер в соответствии с
# таблицей соответствия:
#
# | **Название поля** | **поле в методе POST https://myshop.ru/order/** | **поле сервиса DADATA**   |
# |------------------------|------------------------|------------------------|
# | Индекс            | delivery.address.index                          | data.postal_code          |
# | Регион/ район     | delivery.address.district                       | data.region_with_type     |
# | Город             | delivery.address.city                           | data.city_with_type       |
# | Населённый пункт  | delivery.address.village                        | data.settlement_with_type |
# | Улица             | delivery.address.street                         | data.street_with_type     |
# | Дом               | delivery.address.house                          | data.house                |
# | Корпус / Строение | delivery.address.structure                      | data.block                |
# | Квартира          | delivery.address.flat                           | data.flat                 |
#
# ### Доработка метода отправки заказа
#
# Если клиент выбрал адрес из предложенного списка и отправил заказ на
# обработку (метод POST
# [<u>https://myshop.ru/order/</u>](https://myshop.ru/order/)),
# отправляемый объект дополняется полем ***delivery.isAddressCheck*** со
# значение **true** если значение поля ***data.fias_level*** равно 8 или
# 9.
